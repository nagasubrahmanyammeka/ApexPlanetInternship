# %%
#Data Analytics Internship by ApexPlanet
#Task-1 : Data Immersion and Wragling
#Operation or Task Performed
#1. Dataset Understanding
#2. Data Issues Indentifying
#3. Data Cleaning
#4. Finally Cleaned Data

# %%
import pandas as pd
data = pd.read_csv("socialmedia.csv")
print(data.head())
# Out:
#    user_id   age  daily_screen_time_hours social_media_hours  sleep_hours  \
# 0        1    44                     2.39               1.93         8.46
# 1        2    30                     7.22               5.24         7.34
# 2        3  Null                     2.56               Null         4.69
# 3        4    36                     8.75               4.89         5.05
# 4        5    34                    10.96               2.77         7.12
#
#   exercise_minutes  study_work_hours  productivity_score stress_level  \
# 0               61              3.73               33.86          Low
# 1             Null              6.80               85.32          Low
# 2                8              4.47               60.07         High
# 3               53              9.53               36.46       Medium
# 4               83              7.01               32.93       Medium
#
#     platform
# 0    YouTube
# 1    YouTube
# 2    YouTube
# 3   LinkedIn
# 4  Instagram

# %%
print(data.isnull().sum())
# Out:
# user_id                    0
# age                        0
# daily_screen_time_hours    0
# social_media_hours         0
# sleep_hours                0
# exercise_minutes           0
# study_work_hours           0
# productivity_score         0
# stress_level               0
# platform                   0
# dtype: int64

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  11000 non-null  int64
#  1   age                      11000 non-null  object
#  2   daily_screen_time_hours  11000 non-null  float64
#  3   social_media_hours       11000 non-null  object
#  4   sleep_hours              11000 non-null  float64
#  5   exercise_minutes         11000 non-null  object
#  6   study_work_hours         11000 non-null  float64
#  7   productivity_score       11000 non-null  float64
#  8   stress_level             11000 non-null  object
#  9   platform                 11000 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 859.5+ KB
# None

# %%
data.drop_duplicates(inplace=True)

# %%
print(f"Average Screen Time: {data['daily_screen_time_hours'].mean()}")
# Out:
# Average Screen Time: 6.557201818181818

# %%
data['productivity_hours'] = data['productivity_score']/data['daily_screen_time_hours']
print(data['productivity_hours'])
# Out:
# 0        14.167364
# 1        11.817175
# 2        23.464844
# 3         4.166857
# 4         3.004562
#            ...
# 10995     2.850909
# 10996     5.626901
# 10997    11.696000
# 10998    24.779874
# 10999     5.658892
# Name: productivity_hours, Length: 11000, dtype: float64

# %%
print(data.head())
# Out:
#    user_id   age  daily_screen_time_hours social_media_hours  sleep_hours  \
# 0        1    44                     2.39               1.93         8.46
# 1        2    30                     7.22               5.24         7.34
# 2        3  Null                     2.56               Null         4.69
# 3        4    36                     8.75               4.89         5.05
# 4        5    34                    10.96               2.77         7.12
#
#   exercise_minutes  study_work_hours  productivity_score stress_level  \
# 0               61              3.73               33.86          Low
# 1             Null              6.80               85.32          Low
# 2                8              4.47               60.07         High
# 3               53              9.53               36.46       Medium
# 4               83              7.01               32.93       Medium
#
#     platform  productivity_hours
# 0    YouTube           14.167364
# ...

# %%
data.to_csv("cleaned_new_data.csv",index=False)
print("Data Saved")
# Out:
# Data Saved
